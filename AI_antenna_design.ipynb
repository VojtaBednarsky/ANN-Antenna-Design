# %% [markdown]
# <a href="https://colab.research.google.com/github/VojtaBednarsky/ANN-Antenna-Design/blob/main/AI_antenna_design.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ANN model for training neural network from dataset generated via PDE (Matlab) and futher optimalized in CST microwave Studio

# %%
# %pip install wandb

# %%
# !python antenna-ai.py

# %%
# !wandb agent vojta-bednarsky/Antenna_model/827qfdcz
# Out:
# wandb: Starting wandb agent 🕵️
# 2023-06-08 17:44:09,632 - wandb.wandb_agent - INFO - Running runs: []
# 2023-06-08 17:44:09,920 - wandb.wandb_agent - INFO - Agent received command: run
# 2023-06-08 17:44:09,920 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	af: relu
# 	af2: relu
# 	layers: 5
# 	opt: Adamax
# 	u: 64
# 	u2: 32
# 2023-06-08 17:44:09,921 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python antenna-ai.py --af=relu --af2=relu --layers=5 --opt=Adamax --u=64 --u2=32
# 2023-06-08 17:44:10.588646: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 17:44:12.413318: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-08 17:44:14,935 - wandb.wandb_agent - INFO - Running runs: ['9sxukbuh']
# wandb: Currently logged in as: vojta-bednarsky. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/wandb/run-20230608_174415-9sxukbuh
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run devoted-sweep-154
# wandb: ⭐️ View project at https://wandb.ai/vojta-bednarsky/Antenna_model
# wandb: 🧹 View sweep at https://wandb.ai/vojta-bednarsky/Antenna_model/sweeps/827qfdcz
# wandb: 🚀 View run at https://wandb.ai/vojta-bednarsky/Antenna_model/runs/9sxukbuh
# /usr/local/lib/python3.10/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Traceback (most recent call last):
#   File "/content/antenna-ai.py", line 118, in <module>
#     model.add(Dense(units=u[i], activation=af[i], kernel_initializer=initializer))
# IndexError: list index out of range
# 2023-06-08 17:44:20,012 - wandb.wandb_agent - INFO - Cleaning up finished run: 9sxukbuh
# wandb: Waiting for W&B process to finish... (failed 1). Press Control-C to abort syncing.
# wandb:
# wandb: Run history:
# wandb:       bs ▁
# wandb:      epo ▁
# wandb:   layers ▁
# wandb:       lr ▁
# wandb: lr_decay ▁
# wandb:        m ▁
# wandb:        u ▁
# wandb:       u2 ▁
# wandb:
# wandb: Run summary:
# wandb:       af relu
# wandb:      af2 relu
# wandb:       bs 256
# wandb:      epo 250
# wandb:   layers 5
# wandb:       lr 0.01
# wandb: lr_decay 0.5
# wandb:        m 0.0
# wandb:      opt Adamax
# wandb:        u 64
# wandb:       u2 32
# wandb:
# wandb: 🚀 View run devoted-sweep-154 at: https://wandb.ai/vojta-bednarsky/Antenna_model/runs/9sxukbuh
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230608_174415-9sxukbuh/logs
# 2023-06-08 17:44:25,588 - wandb.wandb_agent - INFO - Agent received command: run
# 2023-06-08 17:44:25,588 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	af: relu
# 	af2: relu
# 	layers: 5
# 	opt: Adamax
# 	u: 64
# 	u2: 64
# 2023-06-08 17:44:25,590 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python antenna-ai.py --af=relu --af2=relu --layers=5 --opt=Adamax --u=64 --u2=64
# 2023-06-08 17:44:26.021454: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 17:44:27.256765: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-08 17:44:30,600 - wandb.wandb_agent - INFO - Running runs: ['etsf7m3k']
# wandb: Currently logged in as: vojta-bednarsky. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/wandb/run-20230608_174431-etsf7m3k
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run dandy-sweep-155
# wandb: ⭐️ View project at https://wandb.ai/vojta-bednarsky/Antenna_model
# wandb: 🧹 View sweep at https://wandb.ai/vojta-bednarsky/Antenna_model/sweeps/827qfdcz
# wandb: 🚀 View run at https://wandb.ai/vojta-bednarsky/Antenna_model/runs/etsf7m3k
# /usr/local/lib/python3.10/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Traceback (most recent call last):
#   File "/content/antenna-ai.py", line 118, in <module>
#     model.add(Dense(units=u[i], activation=af[i], kernel_initializer=initializer))
# IndexError: list index out of range
# wandb: Waiting for W&B process to finish... (failed 1). Press Control-C to abort syncing.
# wandb:
# wandb: Run history:
# wandb:       bs ▁
# wandb:      epo ▁
# wandb:   layers ▁
# wandb:       lr ▁
# wandb: lr_decay ▁
# wandb:        m ▁
# wandb:        u ▁
# wandb:       u2 ▁
# wandb:
# wandb: Run summary:
# wandb:       af relu
# wandb:      af2 relu
# wandb:       bs 256
# wandb:      epo 250
# wandb:   layers 5
# wandb:       lr 0.01
# wandb: lr_decay 0.5
# wandb:        m 0.0
# wandb:      opt Adamax
# wandb:        u 64
# wandb:       u2 64
# wandb:
# wandb: 🚀 View run dandy-sweep-155 at: https://wandb.ai/vojta-bednarsky/Antenna_model/runs/etsf7m3k
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230608_174431-etsf7m3k/logs
# 2023-06-08 17:44:40,738 - wandb.wandb_agent - INFO - Cleaning up finished run: etsf7m3k
# 2023-06-08 17:44:41,044 - wandb.wandb_agent - INFO - Agent received command: run
# 2023-06-08 17:44:41,044 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	af: relu
# 	af2: relu
# 	layers: 5
# 	opt: Adamax
# 	u: 64
# 	u2: 128
# 2023-06-08 17:44:41,045 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python antenna-ai.py --af=relu --af2=relu --layers=5 --opt=Adamax --u=64 --u2=128
# 2023-06-08 17:44:41.488545: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 17:44:42.723227: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-06-08 17:44:46,057 - wandb.wandb_agent - INFO - Running runs: ['16u50vmi']
# wandb: Currently logged in as: vojta-bednarsky. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.15.4
# wandb: Run data is saved locally in /content/wandb/run-20230608_174446-16u50vmi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run glorious-sweep-156
# wandb: ⭐️ View project at https://wandb.ai/vojta-bednarsky/Antenna_model
# wandb: 🧹 View sweep at https://wandb.ai/vojta-bednarsky/Antenna_model/sweeps/827qfdcz
# wandb: 🚀 View run at https://wandb.ai/vojta-bednarsky/Antenna_model/runs/16u50vmi
# /usr/local/lib/python3.10/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Traceback (most recent call last):
#   File "/content/antenna-ai.py", line 118, in <module>
#     model.add(Dense(units=u[i], activation=af[i], kernel_initializer=initializer))
# IndexError: list index out of range
# wandb: Waiting for W&B process to finish... (failed 1). Press Control-C to abort syncing.
# wandb:
# wandb: Run history:
# wandb:       bs ▁
# wandb:      epo ▁
# wandb:   layers ▁
# wandb:       lr ▁
# wandb: lr_decay ▁
# wandb:        m ▁
# wandb:        u ▁
# wandb:       u2 ▁
# wandb:
# wandb: Run summary:
# wandb:       af relu
# wandb:      af2 relu
# wandb:       bs 256
# wandb:      epo 250
# wandb:   layers 5
# wandb:       lr 0.01
# wandb: lr_decay 0.5
# wandb:        m 0.0
# wandb:      opt Adamax
# wandb:        u 64
# wandb:       u2 128
# wandb:
# wandb: 🚀 View run glorious-sweep-156 at: https://wandb.ai/vojta-bednarsky/Antenna_model/runs/16u50vmi
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20230608_174446-16u50vmi/logs
# 2023-06-08 17:44:56,196 - wandb.wandb_agent - ERROR - Detected 3 failed runs in the first 60 seconds, shutting down.
# 2023-06-08 17:44:56,196 - wandb.wandb_agent - INFO - To disable this check set WANDB_AGENT_DISABLE_FLAPPING=true
# wandb: Terminating and syncing runs. Press ctrl-c to kill.
